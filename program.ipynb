# %%
#Crear carpetas para llenar con archivos
#for i in arr:
 #   print(mainpath+'/'+str(i))
  #  os.mkdir(mainpath+'/'+str(i))

# %%
for i in range(len(arr)):
    print(i)
    os.chdir(mainpath+'/'+str(arr[i]))
    print(os.getcwd())
    print(os.listdir())
    print(cartones+'/'+src[i])
    if(i==0):
        j=i
    else:
        j=j+2
    print(cartones+'/'+src[j],mainpath+'/'+str(arr[i]))
    sh.move(cartones+'/'+src[j],mainpath+'/'+str(arr[i]))
    print(cartones+'/'+src[j+1],mainpath+'/'+str(arr[i]))
    sh.move(cartones+'/'+src[j+1],mainpath+'/'+str(arr[i]))
    os.chdir(cartones)
    print(os.getcwd())
    os.system("ls | wc -l")
    os.chdir(mainpath+'/'+str(arr[i]))
    print(os.listdir())
# Out:
# 0
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79456757
# []
# /Users/nicolascastaneda/Documents/Proyectos/Madre/wetransfer_cartones-fecor_2021-12-16_0210/cartones/Ctn 486.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/wetransfer_cartones-fecor_2021-12-16_0210/cartones/Ctn 486.pdf /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79456757
# /Users/nicolascastaneda/Documents/Proyectos/Madre/wetransfer_cartones-fecor_2021-12-16_0210/cartones/Ctn 6.pdf /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79456757
# /Users/nicolascastaneda/Documents/Proyectos/Madre/wetransfer_cartones-fecor_2021-12-16_0210/cartones
#      728
# ['Ctn 486.pdf', 'Ctn 6.pdf']
# 1
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/56084870
# []
# /Users/nicolascastaneda/Documents/Proyectos/Madre/wetransfer_cartones-fecor_2021-12-16_0210/cartones/Ctn 6.pdf
# ...

# %%
d={'79456757':'ricardo.abello@urosario.edu.co','56084870':'viviana.abuchaibe@urosario.edu.co','1014284318':'linaal.acevedo@urosario.edu.co','1023903217':'cindy.acosta@urosario.edu.co','11189299':'german.acosta@urosario.edu.co','51600077':'marianilsa@gmail.com','1013639046':'angie.agudelo@urosario.edu.co','33376887':'mariadelmar.agudelo@gmail.com','22584635':'maria.ahumada@urosario.edu.co','1033723972':'angie.alarcon@urosario.edu.co','40219627':'anama.aldana@urosario.edu.co','1010189441':'sandra.amaya@urosario.edu.co','52473870':'diana.amorteguios@gmail.com','1022342789':'oscar.anaya@urosario.edu.co','53020898':'jennifer.angel@urosario.edu.co','80725775':'john.arbelaezpa@urosario.edu.co','1073691322':'lina.ardila@urosario.edu.co','1030609018':'monica.arevalo@urosario.edu.co','80110946':'nelson.arias@urosario.edu.co','1019100435':'dianaarismendi94@gmail.com','39534107':'nohoraariza@gmail.com','1014255051':'mariacam.avendano@urosario.edu.co','53076394':'monica.avila@urosario.edu.co','53114433':'maribel.avila
u.co','52225711':'angela.rodriguezv@urosario.edu.co','17302312':'jmrojasjumarola@hotmail.com','51775633':'lucila.rojas@urosario.edu.co','39572952':'ana.rojas@urosario.edu.co','79714602':'jhon.rojas@urosario.edu.co','52834098':'angela.rubiano@urosario.edu.co','52500572':'marcela.ruizf@urosario.edu.co','79521463':'juanc.ruiz@urosario.edu.co','7315424':'lruizv@gmail.com','51763428':'alexandra.ruiz@urosario.edu.co','1018432904':'maria.saenz@urosario.edu.co','1012334191':'elizabeth.saenz@urosario.edu.co','1033677672':'jeny.salomon@urosario.edu.co','51900214':'clarab.sanchez@urosario.edu.co','51863787':'sandra.santoyo@urosario.edu.co','53001083':'luisa.sarmiento@urosario.edu.co','1098604149':'normanf.sarmiento@urosario.edu.co','80112989':'samuel.sierra@urosario.edu.co','79145773':'gabriel.silgado@urosario.edu.co','11444725':'jesus.suarez@urosario.edu.co','88234735':'jose.suescun@urosario.edu.co','51776497':'fabitalero@hotmail.com','52778646':'yury.tellez@urosario.edu.co','52495095':'dtolosa79@gmail.com','1015438223':'catherinep.torres@urosario.edu.co','53155266':'yuria.torres@urosario.edu.co','52057346':'martha.torres@urosario.edu.co','1012321719':'florma.torres@urosario.edu.co','52084461':'ana.tovar@urosario.edu.co','52089568':'luisa.urrego@urosario.edu.co','79786330':'alejandro.useche@urosario.edu.co','52749636':'lisethcasallas@hotmail.com','1016036022':'rafael.valenzuela@urosario.edu.co','1019082588':'dianaca.vanegas@urosario.edu.co','51623364':'myriam.vargas@urosario.edu.co','1010201241':'john.vargas@urosario.edu.co','63314790':'olga.vargas@urosario.edu.co','1018436783':'monica.vargast@urosario.edu.co','35469959':'marcela.varona@urosario.edu.co','79792606':'juanp.vasquez@urosario.edu.co','51812356':'claudia.vega@urosario.edu.co','52444066':'angelica.velandia@urosario.edu.co','17140425':'juglora51@hotmail.com','1010195969':'jennyr.velazco@urosario.edu.co','52213693':'sugey.velez@urosario.edu.co','41659935':'pandorapsi@yahoo.es','1032404086':'viviana.villamil@urosario.edu.co','52773361':'mayury.villarreal@urosario.edu.co','52086673':'mary.wilches@urosario.edu.co','52537897':'victoria.yacelga@urosario.edu.co','41535813':'uva5216@gmail.com','80118430':'luis.yaya@urosario.edu.co','53012198':'sandra.yazo@urosario.edu.co','1030593307':'estefania.zapatac@urosario.edu.co','1012383629':'elizabeth.zapata@urosario.edu.co','79645736':'henry.zapata@urosario.edu.co','1010226909':'jenniferd.zuluaga@urosario.edu.co'}

# %%
os.chdir(mainpath)
os.getcwd()
print(d.get(dst[10]))
print(mainpath+'/'+dst[10])
atta=mainpath+'/'+dst[10]
attam=os.listdir(atta)
# Out:
# yuria.torres@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/53155266

# %%
os.chdir(mainpath)
os.getcwd()
l=len(dst)
for i in range(l):
    print(dst[i])
    print(d.get(dst[i]))
    print(mainpath+'/'+dst[i])
    print(os.listdir(mainpath+'/'+dst[i]))
    atta=mainpath+'/'+dst[i]
    attam=os.listdir(atta)
    envio_correo(d.get(dst[i]),atta,attam)
# Out:
# 52086673
# mary.wilches@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/52086673
# ['Ctn 463.pdf', 'Ctn 477.pdf']
# 63309358
# iliana.paez@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/63309358
# ['Ctn 405.pdf', 'Ctn 411.pdf']
# 1023871282
# luzd.jimenez@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1023871282
# ['Ctn 555.pdf', 'Ctn 233.pdf']
# 39784491
# mara.bruges@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/39784491
# ['Ctn 725.pdf', 'Ctn 679.pdf']
# 79521502
# jrestrepo@mincit.gov.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79521502
# ['Ctn 588.pdf', 'Ctn 173.pdf']
# 1016036022
# rafael.valenzuela@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1016036022
# ['Ctn 462.pdf', 'Ctn 22.pdf']
# 52223365
# clemencia.perez@urosario.edu.co
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/52223365
# ...

# %%
def envio_correo(correo,atta1,atta2):
    import smtplib
    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText
    from email.mime.base import MIMEBase
    from email import encoders

    username = "gerenciafecor@urosario.edu.co"
    password = "mnes1964"
    mail_from = "gerenciafecor@urosario.edu.co"
    mail_to = correo
    mail_subject = "¡ BINGO FECOR ! en tu casa........ DOMINGO 19 de diciembre"
    mail_body = "Apreciado(a) asociado(a)  \n Cordial saludo. \n \n Adjunto en formato .pdf encontrará sus cartones asignados. \n \n Este será el enlace de zoom para encontrarnos el próximo DOMINGO 19 DE DICIEMBRE a partir de las 10:00 a.m. \n \n https://us02web.zoom.us/j/85265351876?pwd=ZFRPc3FyalA0YzlLQVN2YmllNnhvdz09  "
    mail_attachment=atta1


    mimemsg = MIMEMultipart()
    mimemsg['From']=mail_from
    mimemsg['To']=mail_to
    mimemsg['Subject']=mail_subject
    mimemsg.attach(MIMEText(mail_body, 'plain'))

    for i in atta2:
        with open(mail_attachment+'/'+i, "rb") as attachment:
            mimefile = MIMEBase('application', 'octet-stream')
            mimefile.set_payload((attachment).read())
            encoders.encode_base64(mimefile)
            mimefile.add_header('Content-Disposition', "attachment; filename= %s" % i)
            mimemsg.attach(mimefile)

    connection = smtplib.SMTP(host='smtp.office365.com', port=587)
    connection.starttls()
    connection.login(username,password)
    connection.send_message(mimemsg)
    connection.quit()

# %%
#os.listdir(mainpath)
for i in arr:
    #print(mainpath+'/'+i)
    #print(os.listdir(mainpath+'/'+i+'/'))
    for j in os.listdir(mainpath+'/'+i+'/'):
        print(mainpath+'/'+i+'/'+j)
        with open('listado3.txt', 'a') as writer:
            writer.write(mainpath+'/'+i+'/'+j+',')
            writer.write('\n')
    writer.close
# Out:
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79456757/Ctn 486.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/79456757/Ctn 6.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/56084870/Ctn 492.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/56084870/Ctn 323.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1014284318/Ctn 445.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1014284318/Ctn 451.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1023903217/Ctn 337.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/1023903217/Ctn 479.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/11189299/Ctn 684.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/11189299/Ctn 39.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/51600077/Ctn 690.pdf
# /Users/nicolascastaneda/Documents/Proyectos/Madre/cedulas/51600077/Ctn 11.pdf
# ...
